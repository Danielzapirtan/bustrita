# %%
# %cd /content/
# !rm -rf bustrita
# !git clone https://github.com/Danielzapirtan/bustrita.git
# %cd bustrita
# !pip install -r requirements.txt
# %run app.py
# Out:
# /content
# Cloning into 'bustrita'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 33 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 15.72 KiB | 2.25 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/bustrita
# ...
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://f58f8807971fed1e43.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# ...
